# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import pathlib

# %%
dataset_url = "https://drive.google.com/uc?id=12KLHLEBr4ss16C90Z7N8sgbHb3qpvUHa"

data_dir = tf.keras.utils.get_file('archives.zip', origin=dataset_url, extract=True)
data_dir = pathlib.Path(data_dir).with_suffix('')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2cbb0b195855> in <cell line: 3>()
#       1 dataset_url = "https://drive.google.com/uc?id=12KLHLEBr4ss16C90Z7N8sgbHb3qpvUHa"
#       2
# ----> 3 data_dir = tf.keras.utils.get_file('archives.zip', origin=dataset_url, extract=True)
#       4 data_dir = pathlib.Path(data_dir).with_suffix('')
#
# NameError: name 'tf' is not defined

# %%
# !pip install gdown
import gdown

# Replace with your actual file ID
file_id = '12KLHLEBr4ss16C90Z7N8sgbHb3qpvUHa'
destination = '/content/archive.zip'

# Download the file from Google Drive
gdown.download(f'https://drive.google.com/uc?id={file_id}', destination, quiet=False)

# Unzip the file if necessary
# !unzip /content/archive.zip -d /content/archive
# Out:
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=12KLHLEBr4ss16C90Z7N8sgbHb3qpvUHa
# From (redirected): https://drive.google.com/uc?id=12KLHLEBr4ss16C90Z7N8sgbHb3qpvUHa&confirm=t&uuid=004c5cc8-15b8-4859-b261-3149dd8f1ba9
# To: /content/archive.zip
# 100%|██████████| 30.6M/30.6M [00:00<00:00, 93.8MB/s]
# Archive:  /content/archive.zip
#   inflating: /content/archive/Multi class garbage classification/labels.txt
#   inflating: /content/archive/Multi class garbage classification/test/cardboard/cardboard108.jpg
#   inflating: /content/archive/Multi class garbage classification/test/cardboard/cardboard114.jpg
#   inflating: /content/archive/Multi class garbage classification/test/cardboard/cardboard115.jpg
#   inflating: /content/archive/Multi class garbage classification/test/cardboard/cardboard116.jpg
#   inflating: /content/archive/Multi class garbage classification/test/cardboard/cardboard117.jpg
# ...
